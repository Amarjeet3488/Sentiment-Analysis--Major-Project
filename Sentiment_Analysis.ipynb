# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarjeet3488/Sentiment-Analysis--Major-Project/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sentiment Analysis using Python

# Approach to Sentiment Analysis
# Lexicon Based Approach:Vader

# %%
# !pip install vaderSentiment
# Out:
# ...
#      |████████████████████████████████| 133kB 5.8MB/s
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'The product is really Awesome!!'
vs.polarity_scores(text)
# Out:
# {'compound': 0.7164, 'neg': 0.0, 'neu': 0.446, 'pos': 0.554}

# %%
text2 = 'This one of the best iPhone ever built, though battery backup isn’t good. But the user experience is brilliant.'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.8674, 'neg': 0.0, 'neu': 0.621, 'pos': 0.379}

# %%
text3 = 'Absolutly bad'
vs.polarity_scores(text3)
# Out:
# {'compound': -0.5423, 'neg': 0.778, 'neu': 0.222, 'pos': 0.0}

# %%
#Gathering of Data using web scraping
# BeautifulSoup, Requests, Scrapy
# using Inshorts

# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
ur1 = 'https://inshorts.com/en/read/sports'
news_data = []
news_category = ur1.split('/')[-1]
news_category
data = requests.get(ur1)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
# ...

# %%
# Using Inshotrs

# %%
ur1s = ['https://inshorts.com/en/read/sports',
       'https://inshorts.com/en/read/world',
       'https://inshorts.com/en/read/technology']

def build_dataset(ur1s):
  news_data = []
  for ur1 in ur1s:
    news_category = ur1.split('/')[-1]
    data = requests.get(ur1)
    soup = BeautifulSoup(data.content)

    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                        'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                        'news_category':news_category}
                      
                      for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                  soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]   
    news_data.extend(news_articles)       

  df = pd.DataFrame(news_data)     
  df = df[['news_headline','news_article','news_category']]  
  return df

# %%
df = build_dataset(ur1s)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  Sachin reached 30,000 international runs durin...  ...        sports
# 1  Ex-Pak batsman Raja once got out obstructing f...  ...        sports
# 2  'Viru Ki Baithak' one of the reasons behind hu...  ...        sports
# 3  Post match, we laughed about it: Suryakumar on...  ...        sports
# 4  Maxwell responds to Sehwag's ₹10-cr cheerleade...  ...        sports
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('/content/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Sachin reached 30,000 international runs durin...  ...        sports
# 1   Ex-Pak batsman Raja once got out obstructing f...  ...        sports
# 2   'Viru Ki Baithak' one of the reasons behind hu...  ...        sports
# 3   Post match, we laughed about it: Suryakumar on...  ...        sports
# 4   Maxwell responds to Sehwag's ₹10-cr cheerleade...  ...        sports
# 5   People say can I do it with other teams, what'...  ...        sports
# 6   Brad Hogg says Rohit's place in Test team unce...  ...        sports
# 7   Babar Azam looks like a million dollar player:...  ...        sports
# 8   I didn’t even know I had contracted coronaviru...  ...        sports
# 9   I couldn't train the day I wasn't picked for A...  ...        sports
# 10  Siraj's father dies at 53, pacer receives news...  ...        sports
# 11  Split captaincy cannot work in our culture, an...  ...        sports
# ...

# %%
# Preprocessing using Tokenization

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 177

# %%
#Remove HTML Tag
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> some important info </h2></html>')
# Out:
# ' some important info '

# %%
# Expand contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all cant't expand I'd think")
# Out:
# ...
#      |████████████████████████████████| 317kB 5.6MB/s
# ...
#      |████████████████████████████████| 245kB 19.4MB/s
# ...
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp36-cp36m-linux_x86_64.whl size=81697 sha256=04b9c1581c867ad2c16b4fef90921100de3124e1718609efb79584c7cf40d23f
#   Stored in directory: /root/.cache/pip/wheels/0a/90/61/87a55f5b459792fbb2b7ba6b31721b06ff5cf6bde541b40994
# Successfully built pyahocorasick
# ...
# "you all can not't expand I would think"

# %%
# Special Char
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'',text)
  return text

remove_sp("+-#skdm")
# Out:
# 'skdm'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  token = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in  stopword_list]
  filtered_text = ''.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and , if are all stopwords and even not")
# Out:
# 'The,,stopwordsevennot'

# %%
# 1- Lower case
# 2- HTMP Tags
# 3- Contractions
# 4- Special char
# 5- Stop words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_headline = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_headline = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_headline = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_headline = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_headline = df.news_article.apply(remove_stopwords)

df
# Out:
#                                         news_headline  ... news_category
# 0   SachinTendulkarbecamefirstbatsmantilldatereach...  ...        sports
# 1   Pakistan'RamizRajabecamefirstbatsmanODIsgetobs...  ...        sports
# 2   WhilecommentingpictureVirenderSehwagInstagram,...  ...        sports
# 3   MI'SuryakumarYadavsaidRCBcaptainViratKohlilaug...  ...        sports
# 4   ReactingVirenderSehwagcalling'₹10-crorecheerle...  ...        sports
# 5   RespondingcriticssuccessMumbaiIndians,captainR...  ...        sports
# 6   Ex-AustraliaspinnerBradHogg,respondingfanTwitt...  ...        sports
# 7   TeamIndiaoff-spinnerRavichandranAshwinsaidPaki...  ...        sports
# 8   SouthAfricaheadcoachMarkBoucherrevealedvictimc...  ...        sports
# 9   MumbaiIndiansbatsmanSuryakumarYadavrevealed'tr...  ...        sports
# 10  IndiafastbowlerMohammedSiraj'fatherMohammedGho...  ...        sports
# 11  AmiddebatewhetherTeamIndiagosplitcaptaincy,Ind...  ...        sports
# ...

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  SachinTendulkarbecamefirstbatsmantilldatereach...  ...   0.0258
# 1  Pakistan'RamizRajabecamefirstbatsmanODIsgetobs...  ...   0.2263
# 2  WhilecommentingpictureVirenderSehwagInstagram,...  ...   0.0000
# 3  MI'SuryakumarYadavsaidRCBcaptainViratKohlilaug...  ...   0.5859
# 4  ReactingVirenderSehwagcalling'₹10-crorecheerle...  ...   0.7269
#
# [5 rows x 4 columns]

# %%
#  Deployment of a model
# using WebApp ( Streamlit/Dash - Python )

# %%
# %%writefile app1.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

df = pd.read_table('https://github.com/Amarjeet3488/Sentiment-Analysis--Major-Project/blob/main/news.csv')
x = df.iloc[:,1].values # Message column as input
y = df.iloc[:,0].values # Label column as output
st.title("Spam Ham Message Classifier")
st.subheader('TFIFD Vectorizer')
st.write('This project is based on Naive Bayes Classifier')

text_model = Pipeline([('tfidf',TfidfVectorizer()),('model',MultinomialNB())])
text_model.fit(x,y)
message = st.text_area("Enter Text","Type Here ..")
op = text_model.predict([message])
if st.button("Predict"):
  st.title(op)
# Out:
# Writing app1.py

# %%
# !pip install streamlit
# Out:
# ...
#      |████████████████████████████████| 7.4MB 4.0MB/s
# ...
#      |████████████████████████████████| 6.9MB 43.3MB/s
# ...
#      |████████████████████████████████| 112kB 48.0MB/s
# ...
#      |████████████████████████████████| 102kB 10.1MB/s
# ...
#      |████████████████████████████████| 4.5MB 35.8MB/s
# ...
#      |████████████████████████████████| 133kB 48.1MB/s
# ...
#      |████████████████████████████████| 163kB 39.5MB/s
# ...
#      |████████████████████████████████| 143kB 45.7MB/s
# ...
#      |████████████████████████████████| 122kB 45.5MB/s
# ...
#      |████████████████████████████████| 71kB 7.6MB/s
# ...
#      |████████████████████████████████| 71kB 8.6MB/s
# ...
#   Created wheel for blinker: filename=blinker-1.4-cp36-none-any.whl size=13450 sha256=0b4b522c0ddba4f4bff7864856947633a43152d374cb06bcaace621cddae4f03
#   Stored in directory: /root/.cache/pip/wheels/92/a0/00/8690a57883956a301d91cf4ec999cc0b258b01e3f548f86e89
# ...

# %%
# !pip install pyngrok==4.1.1
# Out:
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-cp36-none-any.whl size=15971 sha256=5896cd4b4b011823f96d0a8057d1d50235d055cfe121b7d147e7ff1102e96622
#   Stored in directory: /root/.cache/pip/wheels/97/71/0d/1695f7c8815c0beb3b5d9b35d6eec9243c87e6070fbe3977fa
# Successfully built pyngrok
# ...

# %%
from pyngrok import ngrok
url = ngrok.connect(port='8501')
url
# Out:
# 'http://d45830f23547.ngrok.io'

# %%
# !stremlit run app.py&>/dev/null&

# %%
pip install ipython-autotime

# %%
# %load_ext autotime
# Out:
# time: 118 µs

# %%
a = 6
b =8
print(a+b)
# Out:
# 14
# time: 1.29 ms
