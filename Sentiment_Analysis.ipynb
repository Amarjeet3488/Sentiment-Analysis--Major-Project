# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarjeet3488/Sentiment-Analysis--Major-Project/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 5.6MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2.10)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'The product is really Awesome!!'
vs.polarity_scores(text)
# Out:
# {'compound': 0.7164, 'neg': 0.0, 'neu': 0.446, 'pos': 0.554}

# %%
text2 = 'This one of the best iPhone ever built, though battery backup isn’t good. But the user experience is brilliant.'
vs.polarity_scores(text2)
# Out:
# {'compound': 0.8674, 'neg': 0.0, 'neu': 0.621, 'pos': 0.379}

# %%
text3 = 'Absolutly bad'
vs.polarity_scores(text3)
# Out:
# {'compound': -0.5423, 'neg': 0.778, 'neu': 0.222, 'pos': 0.0}

# %%
# web scraping

# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
ur1 = 'https://inshorts.com/en/read/sports'
news_data = []
news_category = ur1.split('/')[-1]
news_category
data = requests.get(ur1)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="ga(" send=""> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/expak-batsman-raja-once-got-out-obstructing-field-running-for-100th-run-1605892381600" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Ex-Pak batsman Raja once got out obstructing field running for 100th run" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/20_fri/img_1605890144382_502.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/20_fri/img_1605890144382_502.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/expak-batsman-raja-once-got-out-obstructing-field-running-for-100th-run-1605892381600" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Ex-Pak%20batsman%20Raja%20once%20got%20out%20obstructing%20field%20running%20for%20100th%20run)' });" style="color:#44444d!important">
# <span itemprop="headline">Ex-Pak batsman Raja once got out obstructing field running for 100th run</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/expak-batsman-raja-once-got-out-obstructing-field-running-for-100th-run-1605892381600"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-11-20T17:13:01.000Z" itemprop="datePublished">10:43 pm</span> on <span clas="date">20 Nov 2020,Friday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Pakistan's Ramiz Raja became the first batsman in ODIs to get out obstructing the field against England on November 20, 1987. Raja was batting on 98 before playing the match's last ball. While trying to take a second run to get to his century, Raja used his bat to prevent the ball from hitting the wickets and was signalled out.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/expak-batsman-raja-once-got-out-obstructing-field-running-for-100th-run-1605892381600"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-11-20T17:13:01.000Z" itemprop="dateModified">10:43 pm</span> on <span class="date">20 Nov</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.cricketcountry.com/articles/8-instances-when-cricketers-were-dismissed-obstructing-the-field-326756/amp/?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Cricket%20Country' });" target="_blank">Cricket Country</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/sachin-reached-30000-international-runs-during-his-88th-century-1605892454080" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Sachin reached 30,000 international runs during his 88th century" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/20_fri/img_1605890277236_94.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/20_fri/img_1605890277236_94.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/sachin-reached-30000-international-runs-during-his-88th-century-1605892454080" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Sachin%20reached%2030%2C000%20international%20runs%20during%20his%2088th%20century)' });" style="color:#44444d!important">
# <span itemprop="headline">Sachin reached 30,000 international runs during his 88th century</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/sachin-reached-30000-international-runs-during-his-88th-century-1605892454080"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-11-20T17:14:14.000Z" itemprop="datePublished">10:44 pm</span> on <span clas="date">20 Nov 2020,Friday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Sachin Tendulkar became the first and the only batsman till date to reach the 30,000-run mark in international cricket on November 20, 2009. Tendulkar achieved the feat on the way to his international career's 88th hundred in a Test against Sri Lanka at Ahmedabad. Sachin ended his career with 34,357 international runs and 100 international hundreds.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/sachin-reached-30000-international-runs-during-his-88th-century-1605892454080"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2020-11-20T17:14:14.000Z" itemprop="dateModified">10:44 pm</span> on <span class="date">20 Nov</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.hindustantimes.com/cricket/sachin-completes-30-000-runs-in-international-cricket/story-u0sqm4Oejk7uQHnFd4hsZI.html?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Hindustan%20Times' });" target="_blank">Hindustan Times</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/people-say-can-i-do-it-with-other-teams-whats-the-need-rohit-on-success-with-mi-1605954009675" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="People say can I do it with other teams, what's the need: Rohit on success with MI" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/21_sat/img_1605951018504_414.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/21_sat/img_1605951018504_414.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/people-say-can-i-do-it-with-other-teams-whats-the-need-rohit-on-success-with-mi-1605954009675" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 
span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/rahane-should-retain-his-own-captaincy-style-in-australia-harbhajan-1605780967851"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2020-11-19T10:16:07.000Z" itemprop="datePublished">03:46 pm</span> on <span clas="date">19 Nov 2020,Thursday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Veteran spinner Harbhajan Singh said Ajinkya Rahane should maintain his distinctive style of captaincy instead of imitating Virat Kohli while leading Team India against Australia in the last three Tests. "That is not necessary, that is not Ajinkya Rahane's style, so he should know how to get the best out of the team while retaining his style," Harbhajan said.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/rahane-should-retain-his-own-captaincy-style-in-australia-harbhajan-1605780967851"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2020-11-19T10:16:07.000Z" itemprop="dateModified">03:46 pm</span> on <span class="date">19 Nov</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.sportskeeda.com/amp/cricket/news-ind-vs-aus-2020-the-test-series-will-huge-challenge-ajinkya-rahane-captain-absence-virat-kohli-harbhajan-singh?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Sportskeeda' });" target="_blank">Sportskeeda</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/continue-with-burns-as-test-opener-dont-disturb-winning-combo-ponting-1605783660913" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Sumit Josh" itemprop="name"></span>
# </span>
# <span content="Continue with Burns as Test opener, don't disturb winning combo: Ponting" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/19_thu/img_1605780927649_599.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/19_thu/img_1605780927649_599.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/continue-with-burns-as-test-opener-dont-disturb-winning-combo-ponting-1605783660913" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Continue%20with%20Burns%20as%20Test%20opener%2C%20don't%20disturb%20winning%20combo%3A%20Ponting)' });" style="color:#44444d!important">
# <span itemprop="headline">Continue with Burns as Test opener, don't disturb winning combo: Ponting</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/continue-with-burns-as-test-opener-dont-disturb-winning-combo-ponting-1605783660913"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2020-11-19T11:01:00.000Z" itemprop="datePublished">04:31 pm</span> on <span clas="date">19 Nov 2020,Thursday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Ex-Australia captain Ricky Ponting said he would request coach Justin Langer to continue with Joe Burns as one of the Test openers against India instead of Will Pucovski and not disturb the winning combination. "Burns hasn't done much wrong...I always say you don't want to be making too many changes if you don't need to," Ponting said.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/continue-with-burns-as-test-opener-dont-disturb-winning-combo-ponting-1605783660913"><span class="short">short</span></a> by <span class="author">Sumit Josh</span> /
#       <span class="time" content="2020-11-19T11:01:00.000Z" itemprop="dateModified">04:31 pm</span> on <span class="date">19 Nov</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2020</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "iovm8hta-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
ur1s = ['https://inshorts.com/en/read/sports',
       'https://inshorts.com/en/read/world',
       'https://inshorts.com/en/read/technology']

def build_dataset(ur1s):
  news_data = []
  for ur1 in ur1s:
    news_category = ur1.split('/')[-1]
    data = requests.get(ur1)
    soup = BeautifulSoup(data.content)

    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                        'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                        'news_category':news_category}
                      
                      for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                  soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]   
    news_data.extend(news_articles)       

  df = pd.DataFrame(news_data)     
  df = df[['news_headline','news_article','news_category']]  
  return df

# %%
df = build_dataset(ur1s)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  Ex-Pak batsman Raja once got out obstructing f...  ...        sports
# 1  Sachin reached 30,000 international runs durin...  ...        sports
# 2  People say can I do it with other teams, what'...  ...        sports
# 3  Maxwell responds to Sehwag's ₹10-cr cheerleade...  ...        sports
# 4  I am absolutely alive and fine: Pak superfan C...  ...        sports
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('/content/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Ex-Pak batsman Raja once got out obstructing f...  ...        sports
# 1   Sachin reached 30,000 international runs durin...  ...        sports
# 2   People say can I do it with other teams, what'...  ...        sports
# 3   Maxwell responds to Sehwag's ₹10-cr cheerleade...  ...        sports
# 4   I am absolutely alive and fine: Pak superfan C...  ...        sports
# 5   I couldn't train the day I wasn't picked for A...  ...        sports
# 6   Wasn't a concern what X, Y or Z was talking ab...  ...        sports
# 7   Cycle mechanic thought I was my sister's serva...  ...        sports
# 8   Brad Hogg says Rohit's place in Test team unce...  ...        sports
# 9   I could see boredom on Kohli's face during IPL...  ...        sports
# 10  Babar Azam looks like a million dollar player:...  ...        sports
# 11  I didn’t even know I had contracted coronaviru...  ...        sports
# 12  Chahal shares video of himself batting in nets...  ...        sports
# 13  Gayle should be in playing XI from game one in...  ...        sports
# 14  Players aged below 15 cannot play internationa...  ...        sports
# 15  AB de Villiers becomes father for the third ti...  ...        sports
# 16  We have to respect Kohli's decision: Laxman on...  ...        sports
# 17  If Kohli has his baby here, we can claim his o...  ...        sports
# 18  Our middle child wants to be Virat Kohli: Davi...  ...        sports
# 19  ICC alters WTC points system due to pandemic, ...  ...        sports
# 20  Wasn't our intention: Belgian Mayor on decorat...  ...         world
# 21  Twitter to transfer @POTUS account to Biden ev...  ...         world
# 22  India summons Pak High Commission officials ov...  ...         world
# 23  'Thank you Elizabeth, LOVE': Trump falls for p...  ...         world
# 24  Singapore man to be charged for holding up smi...  ...         world
# 25  China journo tweets pics of Chinese village al...  ...         world
# 26  Lord Vishnu's 1,300-yr-old temple discovered i...  ...         world
# 27  14 rockets land in various parts of Afghanista...  ...         world
# 28  Big Pharma ran millions of dollars of negative...  ...         world
# 29  Recent COVID-19 vaccine breakthroughs offer a ...  ...         world
# 30  Study that says COVID-19 reinfection unlikely ...  ...         world
# 31  Indian-American Mala Adiga named policy direct...  ...         world
# 32  Philippines ends overseas travel ban on health...  ...         world
# 33     Donald Trump Jr tests positive for coronavirus  ...         world
# 34  Pfizer & BioNTech apply for COVID-19 vaccine e...  ...         world
# 35  Canada's hospitals could be overwhelmed: Trude...  ...         world
# 36  Meghnad Desai resigns from UK Labour Party aft...  ...         world
# 37  Yemen in imminent danger of world’s worst fami...  ...         world
# 38  Armenia appoints new defence minister after Na...  ...         world
# 39  Killing of black man in supermarket sparks vio...  ...         world
# 40  World's most-followed TikTok star loses 1 mn f...  ...    technology
# 41  Twitter to transfer @POTUS account to Biden ev...  ...    technology
# 42  Most common passwords of 2020 revealed, 'ilove...  ...    technology
# 43  Iconic 1,000-foot-wide radio telescope in Puer...  ...    technology
# 44  Vatican asks Instagram to explain how Pope's a...  ...    technology
# 45  Musk a Tesla rally away from dethroning Gates ...  ...    technology
# 46  Ola to introduce its first electric scooter in...  ...    technology
# 47  Amazon firing manufacturing staff working on d...  ...    technology
# 48  Japanese firms to start experimenting with dig...  ...    technology
# 49  Vietnam threatens to ban Facebook over censors...  ...    technology
# 50  Apple, others ask for data protection in Googl...  ...    technology
# 51  Material made from fruits that creates energy ...  ...    technology
# 52  Snapchat-parent Snap acquires music-tech start...  ...    technology
# 53  Financial impact is immaterial: Epic Games CEO...  ...    technology
# 54  Facebook sues man who extracted data of 1 lakh...  ...    technology
# 55  I&B Ministry to decide if online gambling site...  ...    technology
# 56  Foreign hackers may have caused Mumbai's hours...  ...    technology
# 57  Facebook, Google, others threaten to leave Pak...  ...    technology
# 58  Canada's accusations of China being cybercrime...  ...    technology
# 59        US firm creates app to translate cat's meow  ...    technology
#
# [60 rows x 3 columns]

# %%
# Preprocessing

# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 177

# %%
#Remove HTML Tag
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text

html_tag('<html><h2> some important info </h2></html>')
# Out:
# ' some important info '

# %%
# Expand contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand

con("Y'all cant't expand I'd think")
# Out:
# Collecting contractions
#   Downloading https://files.pythonhosted.org/packages/00/92/a05b76a692ac08d470ae5c23873cf1c9a041532f1ee065e74b374f218306/contractions-0.0.25-py2.py3-none-any.whl
# Collecting textsearch
#   Downloading https://files.pythonhosted.org/packages/42/a8/03407021f9555043de5492a2bd7a35c56cc03c2510092b5ec018cae1bbf1/textsearch-0.0.17-py2.py3-none-any.whl
# Collecting pyahocorasick
#   Downloading https://files.pythonhosted.org/packages/f4/9f/f0d8e8850e12829eea2e778f1c90e3c53a9a799b7f412082a5d21cd19ae1/pyahocorasick-1.4.0.tar.gz (312kB)
#      |████████████████████████████████| 317kB 5.5MB/s
# Collecting Unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 14.6MB/s
# Building wheels for collected packages: pyahocorasick
#   Building wheel for pyahocorasick (setup.py) ... done
#   Created wheel for pyahocorasick: filename=pyahocorasick-1.4.0-cp36-cp36m-linux_x86_64.whl size=81702 sha256=3ec83da34dab1867dd8952ade038a3169385184a3baac3ba8dbf98fb25392967
#   Stored in directory: /root/.cache/pip/wheels/0a/90/61/87a55f5b459792fbb2b7ba6b31721b06ff5cf6bde541b40994
# Successfully built pyahocorasick
# Installing collected packages: pyahocorasick, Unidecode, textsearch, contractions
# Successfully installed Unidecode-1.1.1 contractions-0.0.25 pyahocorasick-1.4.0 textsearch-0.0.17
# "you all can not't expand I would think"

# %%
# Special Char
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'',text)
  return text

remove_sp("+-#skdm")
# Out:
# 'skdm'

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  token = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in  stopword_list]
  filtered_text = ''.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords("The, and , if are all stopwords and even not")
# Out:
# 'The,,stopwordsevennot'

# %%
# 1- Lower case
# 2- HTMP Tags
# 3- Contractions
# 4- Special char
# 5- Stop words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_headline = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_headline = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_headline = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_headline = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_headline = df.news_article.apply(remove_stopwords)

df
# Out:
#                                         news_headline  ... news_category
# 0   Pakistan'RamizRajabecamefirstbatsmanODIsgetobs...  ...        sports
# 1   SachinTendulkarbecamefirstbatsmantilldatereach...  ...        sports
# 2   RespondingcriticssuccessMumbaiIndians,captainR...  ...        sports
# 3   ReactingVirenderSehwagcalling'₹10-crorecheerle...  ...        sports
# 4   PakistancricketteamsuperfanChachaCricketakaSuf...  ...        sports
# 5   MumbaiIndiansbatsmanSuryakumarYadavrevealed'tr...  ...        sports
# 6   Talkingcontroversyhamstringinjury,MIcaptainRoh...  ...        sports
# 7   KapilDev,episode#NoFilterNeha,revealedcyclemec...  ...        sports
# 8   Ex-AustraliaspinnerBradHogg,respondingfanTwitt...  ...        sports
# 9   Ex-PakistanpacerShoaibAkhtarsaidViratKohlifeel...  ...        sports
# 10  TeamIndiaoff-spinnerRavichandranAshwinsaidPaki...  ...        sports
# 11  SouthAfricaheadcoachMarkBoucherrevealedvictimc...  ...        sports
# 12  TeamIndialeg-spinnerYuzvendraChahaltookInstagr...  ...        sports
# 13  KingsXIPunjabco-ownerNessWadiasaidChrisGaylefe...  ...        sports
# 14  TheICCintroducedminimumagerestrictionsinternat...  ...        sports
# 15  FormerSouthAfricacaptainABdeVillierstookInstag...  ...        sports
# 16  TalkingTeamIndiacaptainViratKohli'decisiontake...  ...        sports
# 17  TalkingViratKohlitakingpaternityleavebirthfirs...  ...        sports
# 18  AustraliancricketerDavidWarner'wifeCandicerece...  ...        sports
# 19  TheICCtodayannouncedICCWorldTestChampionshippo...  ...        sports
# 20  TheMayorBelgiantownOudenburgadmitted'intention...  ...         world
# 21  Twittertransfer@POTUSaccountJoeBidenInaugurati...  ...         world
# 22  IndiasummonedPakistanHighCommissionofficialsin...  ...         world
# 23  USPresidentDonaldTrumpFridayretweetedarticlefa...  ...         world
# 24  Singaporechargeactiviststagingone-manprotestwi...  ...         world
# 25  ShenShiwei,seniorjournalistChinesestatemedia,t...  ...         world
# 26  AHindutemplededicatedLordVishnu,believedconstr...  ...         world
# 27  Threepeoplekilled11wounded14rocketslandedvario...  ...         world
# 28  USPresidentDonaldTrumpFridayalleged"BigPharmar...  ...         world
# 29  UNSecretary-GeneralAntonioGuterresFridaysaid"r...  ...         world
# 30  WHO'emergenciesheadDrMikeRyansaid"reallygoodne...  ...         world
# 31  USPresident-electJoeBidenFridaynamedIndian-Ame...  ...         world
# 32  PhilippinePresidentRodrigoDuterteliftedbanbarr...  ...         world
# 33  USPresidentDonaldTrump'eldestsonDonaldTrumpJrt...  ...         world
# 34  PfizerGermanpartnerBioNTechappliedEmergencyUse...  ...         world
# 35  CanadianPMJustinTrudeauFridaysaidCOVID-19cases...  ...         world
# 36  Indian-origineconomistLordMeghnadDesairesigned...  ...         world
# 37  UNSecretary-GeneralAntónioGuterressaidYemen"im...  ...         world
# 38  ArmenianPresidentArmenSarkissianappointednewde...  ...         world
# 39  ThekillingblackmantwowhitesecurityguardsCarref...  ...         world
# 40  America'16-year-olddancerCharliD'Amelio,most-f...  ...    technology
# 41  Twittertransfer@POTUSaccountJoeBidenInaugurati...  ...    technology
# 42  PasswordmanagerNordPasspublishedlist200commonp...  ...    technology
# 43  AreciboObservatory'iconic1,000-foot-wideradiot...  ...    technology
# 44  TheVaticansaidseekingexplanationsInstagramPope...  ...    technology
# 45  TeslaCEOElonMuskonerallyTeslasharesawaydethron...  ...    technology
# 46  OlaElectriclaunchingfirstelectricscooterJanuar...  ...    technology
# 47  Amazonreportedlylayingdozensresearchdevelopmen...  ...    technology
# 48  Over30Japanesefirmsbeginexperimentingcommon,pr...  ...    technology
# 49  VietnamthreatenedbanFacebooknotcomplygovernmen...  ...    technology
# 50  Apple,AmazonothersassistedUSgovernmentantitrus...  ...    technology
# 51  Amaterialcreatedrottingfruitsvegetablesgenerat...  ...    technology
# 52  Snapchat-parentSnapreportedlyacquiredUK'music-...  ...    technology
# 53  EpicGamesCEOTimSweeneysaid"financialimpact"App...  ...    technology
# 54  FacebookfiledlawsuitTurkishmanscrapeddata1lakh...  ...    technology
# 55  TheMinistryInformationBroadcastingstartedconsu...  ...    technology
# 56  Thehours-longpowercutMumbaiOctober12couldpossi...  ...    technology
# 57  AsiaInternetCoalition,representativeGoogle,Fac...  ...    technology
# 58  ChineseForeignMinistry'spokespersonZhaoLijians...  ...    technology
# 59  AUS-basedsoftwareengineeringfirmcreatedappreco...  ...    technology
#
# [60 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  Pakistan'RamizRajabecamefirstbatsmanODIsgetobs...  ...   0.2263
# 1  SachinTendulkarbecamefirstbatsmantilldatereach...  ...   0.0258
# 2  RespondingcriticssuccessMumbaiIndians,captainR...  ...   0.7131
# 3  ReactingVirenderSehwagcalling'₹10-crorecheerle...  ...   0.7269
# 4  PakistancricketteamsuperfanChachaCricketakaSuf...  ...  -0.8370
#
# [5 rows x 4 columns]
